# %%
<a target="_blank" href="https://colab.research.google.com/github/Sanali209/Sanali209/blob/master/google%20colab/Notebooks/FastApiServerSample.ipynb">
  <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
</a>
